# %% [markdown]
# # Fraud_Detection_Using_ADASYN_OVERSAMPLING
#
# I am able to achieve the following accuracies in the validation data. These results can be further improved by reducing the
# parameter, number of frauds used to create features from category items. I have used a threshold of 100.
#
# * Logistic Regression :
#         Validation Accuracy: 70.0%, ROC_AUC_Score: 70.0%
#
# * Random Forest :
#         Validation Accuracy: 98.9%, ROC_AUC_Score: 98.9%
#
# * Linear Support Vector Machine :
#         Validation Accuracy: 51.0%, ROC_AUC_Score: 51.1%
#
# * K Nearest Neighbors :
#         Validation Accuracy: 86.7%, ROC_AUC_Score: 86.7%
#
# * Extra Trees Classifer :
#         Validation Accuracy: 99.2%, ROC_AUC_Score: 99.2%

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn import svm, neighbors
from sklearn.naive_bayes import GaussianNB
from imblearn.over_sampling import SMOTE, ADASYN
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
import itertools
% matplotlib inline
# Out:
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# ### Loading Training Transactions Data

# %%
tr_tr = pd.read_csv('data/train_transaction.csv', index_col='TransactionID')
print('Rows :', tr_tr.shape[0],'  Columns : ',tr_tr.shape[1] )
tr_tr.tail()
print('Memory Usage : ', (tr_tr.memory_usage(deep=True).sum()/1024).round(0))
tr_tr.tail()
# Out:
# Rows : 590540   Columns :  393
# Memory Usage :  2162614.0
#                isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  \
# TransactionID
# 3577535              0       15811047           49.00         W   6550    NaN
# 3577536              0       15811049           39.50         W  10444  225.0
# 3577537              0       15811079           30.95         W  12037  595.0
# 3577538              0       15811088          117.00         W   7826  481.0
# 3577539              0       15811131          279.95         W  15066  170.0
#
#                card3       card4  card5   card6  ...   V330  V331  V332  V333  \
# TransactionID                                    ...
# 3577535        150.0        visa  226.0   debit  ...    NaN   NaN   NaN   NaN
# 3577536        150.0  mastercard  224.0   debit  ...    NaN   NaN   NaN   NaN
# 3577537        150.0  mastercard  224.0   debit  ...    NaN   NaN   NaN   NaN
# 3577538        150.0  mastercard  224.0   debit  ...    NaN   NaN   NaN   NaN
# 3577539        150.0  mastercard  102.0  credit  ...    NaN   NaN   NaN   NaN
#
#               V334 V335  V336  V337  V338  V339
# TransactionID
# 3577535        NaN  NaN   NaN   NaN   NaN   NaN
# 3577536        NaN  NaN   NaN   NaN   NaN   NaN
# 3577537        NaN  NaN   NaN   NaN   NaN   NaN
# 3577538        NaN  NaN   NaN   NaN   NaN   NaN
# 3577539        NaN  NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 393 columns]

# %%
tr_id = pd.read_csv('data/train_identity.csv', index_col='TransactionID')
print(tr_id.shape)
tr_id.tail()
# Out:
# (144233, 40)
#                id_01     id_02  id_03  id_04  id_05  id_06  id_07  id_08  \
# TransactionID
# 3577521        -15.0  145955.0    0.0    0.0    0.0    0.0    NaN    NaN
# 3577526         -5.0  172059.0    NaN    NaN    1.0   -5.0    NaN    NaN
# 3577529        -20.0  632381.0    NaN    NaN   -1.0  -36.0    NaN    NaN
# 3577531         -5.0   55528.0    0.0    0.0    0.0   -7.0    NaN    NaN
# 3577534        -45.0  339406.0    NaN    NaN  -10.0 -100.0    NaN    NaN
#
#                id_09  id_10                 ...                  \
# TransactionID                               ...
# 3577521          0.0    0.0                 ...
# 3577526          NaN    NaN                 ...
# 3577529          NaN    NaN                 ...
# 3577531          0.0    0.0                 ...
# 3577534          NaN    NaN                 ...
#
#                                  id_31 id_32      id_33           id_34 id_35  \
# TransactionID
# 3577521        chrome 66.0 for android   NaN        NaN             NaN     F
# 3577526        chrome 55.0 for android  32.0    855x480  match_status:2     T
# 3577529        chrome 65.0 for android   NaN        NaN             NaN     F
# 3577531                    chrome 66.0  24.0  2560x1600  match_status:2     T
# 3577534        chrome 66.0 for android   NaN        NaN             NaN     F
#
#               id_36  id_37  id_38  DeviceType  \
# TransactionID
# 3577521           F      T      F      mobile
# 3577526           F      T      F      mobile
# 3577529           F      T      F      mobile
# 3577531           F      T      F     desktop
# 3577534           F      T      F      mobile
#
#                                        DeviceInfo
# TransactionID
# 3577521                   F3111 Build/33.3.A.1.97
# 3577526                       A574BL Build/NMF26F
# 3577529        Moto E (4) Plus Build/NMA26.42-152
# 3577531                                     MacOS
# 3577534               RNE-L03 Build/HUAWEIRNE-L03
#
# [5 rows x 40 columns]

# %%
tr = tr_tr.join(tr_id)
tr['data']='train'
print(tr.shape)
tr.head()
# Out:
# (590540, 434)
#                isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  \
# TransactionID
# 2987000              0          86400            68.5         W  13926    NaN
# 2987001              0          86401            29.0         W   2755  404.0
# 2987002              0          86469            59.0         W   4663  490.0
# 2987003              0          86499            50.0         W  18132  567.0
# 2987004              0          86506            50.0         H   4497  514.0
#
#                card3       card4  card5   card6  ...    id_32      id_33  \
# TransactionID                                    ...
# 2987000        150.0    discover  142.0  credit  ...      NaN        NaN
# 2987001        150.0  mastercard  102.0  credit  ...      NaN        NaN
# 2987002        150.0        visa  166.0   debit  ...      NaN        NaN
# 2987003        150.0  mastercard  117.0   debit  ...      NaN        NaN
# 2987004        150.0  mastercard  102.0  credit  ...     32.0  2220x1080
#
#                         id_34  id_35 id_36 id_37  id_38  DeviceType  \
# TransactionID
# 2987000                   NaN    NaN   NaN   NaN    NaN         NaN
# 2987001                   NaN    NaN   NaN   NaN    NaN         NaN
# 2987002                   NaN    NaN   NaN   NaN    NaN         NaN
# 2987003                   NaN    NaN   NaN   NaN    NaN         NaN
# 2987004        match_status:2      T     F     T      T      mobile
#
#                                   DeviceInfo   data
# TransactionID
# 2987000                                  NaN  train
# 2987001                                  NaN  train
# 2987002                                  NaN  train
# 2987003                                  NaN  train
# 2987004        SAMSUNG SM-G892A Build/NRD90M  train
#
# [5 rows x 434 columns]

# %%
del tr_tr
del tr_id

# %%
te_tr = pd.read_csv('data/test_transaction.csv', index_col='TransactionID')
print(te_tr.shape)
te_tr.tail()
# Out:
# (506691, 392)
#                TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# TransactionID
# 4170235             34214279          94.679         C  13832  375.0  185.0
# 4170236             34214287          12.173         C   3154  408.0  185.0
# 4170237             34214326          49.000         W  16661  490.0  150.0
# 4170238             34214337         202.000         W  16621  516.0  150.0
# 4170239             34214345          24.346         C   5713  168.0  144.0
#
#                     card4  card5   card6  addr1  ...   V330  V331  V332 V333  \
# TransactionID                                    ...
# 4170235        mastercard  224.0   debit  284.0  ...    NaN   NaN   NaN  NaN
# 4170236        mastercard  224.0   debit    NaN  ...    NaN   NaN   NaN  NaN
# 4170237              visa  226.0   debit  327.0  ...    NaN   NaN   NaN  NaN
# 4170238        mastercard  224.0   debit  177.0  ...    NaN   NaN   NaN  NaN
# 4170239              visa  147.0  credit    NaN  ...    NaN   NaN   NaN  NaN
#
#               V334  V335  V336  V337  V338  V339
# TransactionID
# 4170235        NaN   NaN   NaN   NaN   NaN   NaN
# 4170236        NaN   NaN   NaN   NaN   NaN   NaN
# 4170237        NaN   NaN   NaN   NaN   NaN   NaN
# 4170238        NaN   NaN   NaN   NaN   NaN   NaN
# 4170239        NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 392 columns]

# %%
te_id = pd.read_csv('data/test_identity.csv', index_col='TransactionID')
print(te_id.shape)
te_id.tail()
# Out:
# (141907, 40)
#                id_01     id_02  id_03  id_04  id_05  id_06  id_07  id_08  \
# TransactionID
# 4170230        -20.0  473365.0    NaN    NaN    0.0    0.0    NaN    NaN
# 4170233         -5.0  489917.0    0.0    0.0   -4.0  -32.0    NaN    NaN
# 4170234         -5.0  110081.0    NaN    NaN   22.0  -31.0    NaN    NaN
# 4170236        -45.0  266704.0    NaN    NaN   -3.0  -10.0    NaN    NaN
# 4170239        -10.0  692090.0    0.0    0.0    0.0    0.0    NaN    NaN
#
#                id_09  id_10             ...               \
# TransactionID                           ...
# 4170230          NaN    NaN             ...
# 4170233          0.0    0.0             ...
# 4170234          NaN    NaN             ...
# 4170236          NaN    NaN             ...
# 4170239          0.0    0.0             ...
#
#                                  id_31 id_32     id_33           id_34 id_35  \
# TransactionID
# 4170230        chrome 71.0 for android   NaN       NaN             NaN     F
# 4170233        chrome 71.0 for android   NaN       NaN             NaN     F
# 4170234             mobile safari 10.0  32.0  1334x750  match_status:2     T
# 4170236        chrome 43.0 for android   NaN       NaN             NaN     F
# 4170239            samsung browser 8.2   NaN       NaN             NaN     F
#
#               id_36  id_37  id_38  DeviceType                   DeviceInfo
# TransactionID
# 4170230           F      T      F      mobile                     SM-J700M
# 4170233           F      T      F      mobile                     SM-J320M
# 4170234           F      F      T      mobile                   iOS Device
# 4170236           F      T      F      mobile  ALE-L23 Build/HuaweiALE-L23
# 4170239           F      T      F      mobile                      SAMSUNG
#
# [5 rows x 40 columns]

# %%
te = te_tr.join(te_id)
te['data']='test'
te['isFraud']=2
print(te.shape)
te.head()
# Out:
# (506691, 434)
#                TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# TransactionID
# 3663549             18403224           31.95         W  10409  111.0  150.0
# 3663550             18403263           49.00         W   4272  111.0  150.0
# 3663551             18403310          171.00         W   4476  574.0  150.0
# 3663552             18403310          284.95         W  10989  360.0  150.0
# 3663553             18403317           67.95         W  18018  452.0  150.0
#
#                     card4  card5  card6  addr1   ...     id_33  id_34  id_35  \
# TransactionID                                    ...
# 3663549              visa  226.0  debit  170.0   ...       NaN    NaN    NaN
# 3663550              visa  226.0  debit  299.0   ...       NaN    NaN    NaN
# 3663551              visa  226.0  debit  472.0   ...       NaN    NaN    NaN
# 3663552              visa  166.0  debit  205.0   ...       NaN    NaN    NaN
# 3663553        mastercard  117.0  debit  264.0   ...       NaN    NaN    NaN
#
#               id_36 id_37  id_38  DeviceType  DeviceInfo  data  isFraud
# TransactionID
# 3663549         NaN   NaN    NaN         NaN         NaN  test        2
# 3663550         NaN   NaN    NaN         NaN         NaN  test        2
# 3663551         NaN   NaN    NaN         NaN         NaN  test        2
# 3663552         NaN   NaN    NaN         NaN         NaN  test        2
# 3663553         NaN   NaN    NaN         NaN         NaN  test        2
#
# [5 rows x 434 columns]

# %%
del te_tr
del te_id

# %%
tr.isFraud.describe()
# Out:
# count    590540.000000
# mean          0.034990
# std           0.183755
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: isFraud, dtype: float64

# %%
tr.isFraud.value_counts().plot(kind='bar')
tr.isFraud.value_counts()
# Out:
# 0    569877
# 1     20663
# Name: isFraud, dtype: int64

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(12,4))
ax1.hist(tr.TransactionAmt[tr.isFraud == 1], bins = 10)
ax1.set_title('Fraud Transactions ='+str(tr.isFraud.value_counts()[1]))
ax2.hist(tr.TransactionAmt[tr.isFraud == 0], bins = 10)
ax2.set_title('Normal Transactions ='+str(tr.isFraud.value_counts()[0]))
plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.yscale('log')
plt.show()

# %%
sns.distplot(tr['TransactionAmt'], color='red')
# Out:
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(tr[['TransactionAmt','isFraud']], hue='isFraud')
# Out:
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\kenneth\Anaconda3\envs\gpu\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
df = pd.concat([tr,te], sort=False)
print(df.shape)
df.head()
# Out:
# (1097231, 434)
#                isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  \
# TransactionID
# 2987000              0          86400            68.5         W  13926    NaN
# 2987001              0          86401            29.0         W   2755  404.0
# 2987002              0          86469            59.0         W   4663  490.0
# 2987003              0          86499            50.0         W  18132  567.0
# 2987004              0          86506            50.0         H   4497  514.0
#
#                card3       card4  card5   card6  ...    id_32      id_33  \
# TransactionID                                    ...
# 2987000        150.0    discover  142.0  credit  ...      NaN        NaN
# 2987001        150.0  mastercard  102.0  credit  ...      NaN        NaN
# 2987002        150.0        visa  166.0   debit  ...      NaN        NaN
# 2987003        150.0  mastercard  117.0   debit  ...      NaN        NaN
# 2987004        150.0  mastercard  102.0  credit  ...     32.0  2220x1080
#
#                         id_34  id_35 id_36 id_37  id_38  DeviceType  \
# TransactionID
# 2987000                   NaN    NaN   NaN   NaN    NaN         NaN
# 2987001                   NaN    NaN   NaN   NaN    NaN         NaN
# 2987002                   NaN    NaN   NaN   NaN    NaN         NaN
# 2987003                   NaN    NaN   NaN   NaN    NaN         NaN
# 2987004        match_status:2      T     F     T      T      mobile
#
#                                   DeviceInfo   data
# TransactionID
# 2987000                                  NaN  train
# 2987001                                  NaN  train
# 2987002                                  NaN  train
# 2987003                                  NaN  train
# 2987004        SAMSUNG SM-G892A Build/NRD90M  train
#
# [5 rows x 434 columns]

# %%
del tr
del te

# %% [markdown]
# ### Make new category for items in Objects with A Fraud Count of more than 100

# %%
fraud_threshold = 100

def map_categories(*args):
    columns = [col for col in args]
    for column in columns:
        if column == index:
            return 1
        else:
            return 0
new_categories = []
for i in df.columns:
    if i != 'data':
        if df[i].dtypes == str('object'):
            fraud_count = df[df.isFraud==1][i].value_counts(dropna=False)
            for index, value in fraud_count.items():
                if value>fraud_threshold:
                    df[(str(i)+'_'+str(index))]=list(map(map_categories, df[i]))
                    new_categories.append((str(i)+'_'+str(index)))
    #             else:
    #                 tr[(str(i)+'_'+str('other'))]=list(map(map_categories, tr[i]))
    #                 new_tr_categories.append((str(i)+'_'+str('other')))
            df.drop([i], axis=1, inplace=True)
print(new_categories)
print(df.shape)
df.head()
# Out:
# ['ProductCD_W', 'ProductCD_C', 'ProductCD_H', 'ProductCD_R', 'ProductCD_S', 'card4_visa', 'card4_mastercard', 'card4_discover', 'card4_american express', 'card6_debit', 'card6_credit', 'P_emaildomain_gmail.com', 'P_emaildomain_nan', 'P_emaildomain_hotmail.com', 'P_emaildomain_yahoo.com', 'P_emaildomain_anonymous.com', 'P_emaildomain_aol.com', 'P_emaildomain_outlook.com', 'P_emaildomain_comcast.net', 'P_emaildomain_icloud.com', 'P_emaildomain_mail.com', 'R_emaildomain_nan', 'R_emaildomain_gmail.com', 'R_emaildomain_hotmail.com', 'R_emaildomain_yahoo.com', 'R_emaildomain_anonymous.com', 'R_emaildomain_outlook.com', 'R_emaildomain_icloud.com', 'R_emaildomain_aol.com', 'M1_nan', 'M1_T', 'M2_nan', 'M2_T', 'M2_F', 'M3_nan', 'M3_T', 'M3_F', 'M4_M0', 'M4_M2', 'M4_nan', 'M4_M1', 'M5_nan', 'M5_T', 'M5_F', 'M6_nan', 'M6_F', 'M6_T', 'M7_nan', 'M7_F', 'M7_T', 'M8_nan', 'M8_F', 'M8_T', 'M9_nan', 'M9_T', 'M9_F', 'id_12_NotFound', 'id_12_nan', 'id_12_Found', 'id_15_nan', 'id_15_Found', 'id_15_New', 'id_15_Unknown', 'id_16_nan', 'id_16_Found', 'id_16_NotFound', 'id_23_nan', 'id_23_IP_PROXY:TRANSPARENT', 'id_23_IP_PROXY:ANONYMOUS', 'id_27_nan', 'id_27_Found', 'id_28_nan', 'id_28_Found', 'id_28_New', 'id_29_nan', 'id_29_Found', 'id_29_NotFound', 'id_30_nan', 'id_30_Windows 10', 'id_30_Windows 7', 'id_30_iOS 11.2.1', 'id_30_Android 7.0', 'id_30_iOS 11.2.5', 'id_30_iOS 11.3.0', 'id_30_Windows 8.1', 'id_30_iOS 11.1.2', 'id_30_Android', 'id_30_iOS 11.2.2', 'id_30_Android 5.1.1', 'id_31_nan', 'id_31_chrome 63.0', 'id_31_mobile safari generic', 'id_31_mobile safari 11.0', 'id_31_chrome generic', 'id_31_chrome 65.0', 'id_31_chrome 63.0 for android', 'id_31_chrome 64.0', 'id_31_chrome 64.0 for android', 'id_31_chrome 65.0 for android', 'id_31_chrome 66.0', 'id_31_chrome 66.0 for android', 'id_31_chrome 62.0', 'id_31_safari generic', 'id_31_firefox 57.0', 'id_31_ie 11.0 for desktop', 'id_31_chrome 62.0 for android', 'id_31_firefox', 'id_31_mobile safari 10.0', 'id_31_chrome generic for android', 'id_31_edge 16.0', 'id_33_nan', 'id_33_1366x768', 'id_33_1920x1080', 'id_33_2208x1242', 'id_33_1334x750', 'id_33_1280x720', 'id_33_2436x1125', 'id_33_1440x900', 'id_33_1600x900', 'id_33_1280x800', 'id_34_nan', 'id_34_match_status:2', 'id_34_match_status:1', 'id_35_nan', 'id_35_F', 'id_35_T', 'id_36_F', 'id_36_nan', 'id_36_T', 'id_37_nan', 'id_37_T', 'id_37_F', 'id_38_nan', 'id_38_F', 'id_38_T', 'DeviceType_nan', 'DeviceType_mobile', 'DeviceType_desktop', 'DeviceInfo_nan', 'DeviceInfo_Windows', 'DeviceInfo_iOS Device', 'DeviceInfo_MacOS', 'DeviceInfo_hi6210sft Build/MRA58K', 'DeviceInfo_SM-A300H Build/LRX22G', 'DeviceInfo_rv:57.0']
# (1097231, 548)
#                isFraud  TransactionDT  TransactionAmt  card1  card2  card3  \
# TransactionID
# 2987000              0          86400            68.5  13926    NaN  150.0
# 2987001              0          86401            29.0   2755  404.0  150.0
# 2987002              0          86469            59.0   4663  490.0  150.0
# 2987003              0          86499            50.0  18132  567.0  150.0
# 2987004              0          86506            50.0   4497  514.0  150.0
#
#                card5  addr1  addr2  dist1         ...          DeviceType_nan  \
# TransactionID                                     ...
# 2987000        142.0  315.0   87.0   19.0         ...                       0
# 2987001        102.0  325.0   87.0    NaN         ...                       0
# 2987002        166.0  330.0   87.0  287.0         ...                       0
# 2987003        117.0  476.0   87.0    NaN         ...                       0
# 2987004        102.0  420.0   87.0    NaN         ...                       0
#
#                DeviceType_mobile  DeviceType_desktop  DeviceInfo_nan  \
# TransactionID
# 2987000                        0                   0               0
# 2987001                        0                   0               0
# 2987002                        0                   0               0
# 2987003                        0                   0               0
# 2987004                        1                   0               0
#
#                DeviceInfo_Windows  DeviceInfo_iOS Device  DeviceInfo_MacOS  \
# TransactionID
# 2987000                         0                      0                 0
# 2987001                         0                      0                 0
# 2987002                         0                      0                 0
# 2987003                         0                      0                 0
# 2987004                         0                      0                 0
#
#                DeviceInfo_hi6210sft Build/MRA58K  \
# TransactionID
# 2987000                                        0
# 2987001                                        0
# 2987002                                        0
# 2987003                                        0
# 2987004                                        0
#
#                DeviceInfo_SM-A300H Build/LRX22G  DeviceInfo_rv:57.0
# TransactionID
# 2987000                                       0                   0
# 2987001                                       0                   0
# 2987002                                       0                   0
# 2987003                                       0                   0
# 2987004                                       0                   0
#
# [5 rows x 548 columns]

# %%
df.isna().any().mean()
# Out:
# 0.7262773722627737

# %%
df.fillna(0, inplace=True)
df.isna().any().mean()
# Out:
# 0.0

# %%
X = df[df['data'] == 'train'].drop(['isFraud','data'], axis=1)
y = df[df['data'] == 'train']['isFraud']

# %%
X_predict = df[df['data'] == 'test'].drop(['isFraud','data'], axis=1)

# %%
print(X.shape, y.shape, X_predict.shape)
# Out:
# (590540, 546) (590540,) (506691, 546)

# %% [markdown]
# ### Oversampling using ADASYN

# %%
ada = ADASYN(random_state=91)
X_sampled,y_sampled = ada.fit_sample(X,y)

# %%
#fraudlent records in original data
y.value_counts()
# Out:
# 0    569877
# 1     20663
# Name: isFraud, dtype: int64

# %%
#fraudlent records in oversampled data is is almost equal to normal data
np.bincount(y_sampled)
# Out:
# array([569877, 565805], dtype=int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sampled,y_sampled,test_size=0.3)

# %%
class_names = ['FRAUD', 'NORMAL']


def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('Ground Truth')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Logistic Regression

# %%
lr = LogisticRegression(solver='lbfgs')
clf_lr = lr.fit(X_train, y_train)
confidence_lr=clf_lr.score(X_test, y_test)
print('Accuracy on Validation Data : ', confidence_lr.round(2)*100,'%')
# Out:
# Accuracy on Validation Data :  70.0 %

# %%
test_prediction = clf_lr.predict(X_test)
print('ROC_AUC_SCORE ; ', roc_auc_score(y_test, test_prediction).round(3)*100,'%')
cnf_matrix = confusion_matrix(y_test, test_prediction)
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix')
# Out:
# ROC_AUC_SCORE ;  69.69999999999999 %
# [[128202  42828]
#  [ 60415 109260]]

# %%
prediction_lr = clf_lr.predict(X_predict)
test = df[df['data'] == 'test']
del df
test['prediction_lr'] = prediction_lr

# %%
test.prediction_lr.value_counts()
# Out:
# 0    308678
# 1    198013
# Name: prediction_lr, dtype: int64

# %%
test.prediction_lr.to_csv('adLogistic_Regression_Prediction.csv')

# %% [markdown]
# ### Random Forest

# %%
rfor=RandomForestClassifier()
clf_rfor = rfor.fit(X_train, y_train)
confidence_rfor=clf_rfor.score(X_test, y_test)
print('Accuracy on Validation Data : ', confidence_rfor.round(3)*100,'%')
# Out:
# Accuracy on Validation Data :  98.9 %

# %%
test_prediction = clf_rfor.predict(X_test)
print('ROC_AUC_SCORE ; ', roc_auc_score(y_test, test_prediction).round(3)*100,'%')
cnf_matrix = confusion_matrix(y_test, test_prediction)
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix')
# Out:
# ROC_AUC_SCORE ;  98.9 %
# [[170677    353]
#  [  3402 166273]]

# %%
prediction_rfor = clf_rfor.predict(X_predict)
test['prediction_rfor'] = prediction_rfor

# %%
test.prediction_rfor.value_counts()
# Out:
# 0    498758
# 1      7933
# Name: prediction_rfor, dtype: int64

# %%
test.prediction_rfor.to_csv('adRandom_Forest_Prediction.csv')

# %% [markdown]
# ### Linear Support Vector Machine Algorithm

# %%
lsvc=svm.LinearSVC()
clf_lsvc=lsvc.fit(X_train, y_train)
confidence_lsvc=clf_lsvc.score(X_test, y_test)
print('Accuracy on Validation Data : ', confidence_lsvc.round(3)*100,'%')
# Out:
# Accuracy on Validation Data :  51.0 %

# %%
test_prediction = clf_lsvc.predict(X_test)
print('ROC_AUC_SCORE ; ', roc_auc_score(y_test, test_prediction).round(3)*100,'%')
cnf_matrix = confusion_matrix(y_test, test_prediction)
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix')
# Out:
# ROC_AUC_SCORE ;  51.1 %
# [[  5149 165881]
#  [  1209 168466]]

# %% [markdown]
# ### K-Nearest Neighbors Algorithm

# %%
knn=neighbors.KNeighborsClassifier(n_neighbors=10, n_jobs=-1)
clf_knn=knn.fit(X_train, y_train)
confidence_knn=clf_knn.score(X_test, y_test)
print('Accuracy on Validation Data : ', confidence_knn.round(3)*100,'%')
# Out:
# Accuracy on Validation Data :  86.7 %

# %%
test_prediction = clf_knn.predict(X_test)
print('ROC_AUC_SCORE ; ', roc_auc_score(y_test, test_prediction).round(3)*100,'%')
cnf_matrix = confusion_matrix(y_test, test_prediction)
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix')
# Out:
# ROC_AUC_SCORE ;  86.7 %
# [[136578  34452]
#  [ 10938 158737]]

# %% [markdown]
# ### Extra Trees Classifier

# %%
etc=ExtraTreesClassifier()
clf_etc = etc.fit(X_train, y_train)
confidence_etc=clf_etc.score(X_test, y_test)
print('Accuracy on Validation Data : ', confidence_etc.round(3)*100,'%')
# Out:
# Accuracy on Validation Data :  99.2 %

# %%
test_prediction = clf_etc.predict(X_test)
print('ROC_AUC_SCORE ; ', roc_auc_score(y_test, test_prediction).round(3)*100,'%')
cnf_matrix = confusion_matrix(y_test, test_prediction)
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix')
# Out:
# ROC_AUC_SCORE ;  99.2 %
# [[170544    486]
#  [  2098 167577]]

# %%
prediction_etc = clf_etc.predict(X_predict)
test['prediction_etc'] = prediction_etc

# %%
test.prediction_etc.value_counts()
# Out:
# 0    498069
# 1      8622
# Name: prediction_etc, dtype: int64

# %%
test.prediction_etc.to_csv('adExtra_Trees_Prediction.csv')
